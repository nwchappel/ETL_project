# %%
import pandas as pd
from sqlalchemy import create_engine
import geopandas as gpd

# %% [markdown]
# ### Store CSV into DataFrame

# %%
schools_csv = "Resources/Public_Schools.csv"
school_data_df = pd.read_csv(schools_csv)
school_data_df.head()
# Out:
#            X          Y  OBJECTID_1  OBJECTID  BLDG_ID              BLDG_NAME  \
# 0 -71.004121  42.388799           1         1        1             Guild Bldg
# 1 -71.030480  42.378545           2         2        3        Kennedy, P Bldg
# 2 -71.033891  42.375279           3         3        4              Otis Bldg
# 3 -71.038011  42.378089           4         4        6          Odonnell Bldg
# 4 -71.034921  42.380957           5         5        7  East Boston High Bldg
#
#                ADDRESS         CITY  ZIPCODE  CSP_SCH_ID  ...  \
# 0    195 Leyden Street  East Boston     2128        4061  ...
# 1  343 Saratoga Street  East Boston     2128        4541  ...
# 2    218 Marion Street  East Boston     2128        4322  ...
# 3    33 Trenton Street  East Boston     2128        4543  ...
# 4      86 White Street  East Boston     2128        1070  ...
#
#                SCH_NAME       SCH_LABEL SCH_TYPE SHARED COMPLEX Label  TLT  \
# ...

# %%
# offense_code_csv = "Resources/offense_codes.csv"
# offense_codes_df = pd.read_csv(offense_code_csv)
# offense_codes_df.head()

# %%
schools_json = "Resources/Public_Schools.geojson"
schools_json_df = pd.read_json(schools_json)
schools_json_df.head()
# Out:
#                 type                                           features
# 0  FeatureCollection  {'type': 'Feature', 'properties': {'OBJECTID_1...
# 1  FeatureCollection  {'type': 'Feature', 'properties': {'OBJECTID_1...
# 2  FeatureCollection  {'type': 'Feature', 'properties': {'OBJECTID_1...
# 3  FeatureCollection  {'type': 'Feature', 'properties': {'OBJECTID_1...
# 4  FeatureCollection  {'type': 'Feature', 'properties': {'OBJECTID_1...
